# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('data/survey_results_public.csv', index_col='Respondent')
schema_df = pd.read_csv('data/survey_results_schema.csv', index_col='Column')

# %%
pd.set_option('display.max_columns', 85)
pd.set_option('display.max_rows', 85)

# %%
df.head()
# Out:
#                                                    MainBranch Hobbyist   Age  \
# Respondent
# 1                              I am a developer by profession      Yes   NaN
# 2                              I am a developer by profession       No   NaN
# 3                                 I code primarily as a hobby      Yes   NaN
# 4                              I am a developer by profession      Yes  25.0
# 5           I used to be a developer by profession, but no...      Yes  31.0
#
#            Age1stCode CompFreq  CompTotal  ConvertedComp             Country  \
# Respondent
# 1                  13  Monthly        NaN            NaN             Germany
# 2                  19      NaN        NaN            NaN      United Kingdom
# 3                  15      NaN        NaN            NaN  Russian Federation
# 4                  18      NaN        NaN            NaN             Albania
# 5                  16      NaN        NaN            NaN       United States
#
# ...

# %%
df.describe()
# Out:
#                 Age      CompTotal  ConvertedComp   WorkWeekHrs
# count  45446.000000   3.482600e+04   3.475600e+04  41151.000000
# mean      30.834111  3.190464e+242   1.037561e+05     40.782174
# std        9.585392            inf   2.268853e+05     17.816383
# min        1.000000   0.000000e+00   0.000000e+00      1.000000
# 25%       24.000000   2.000000e+04   2.464800e+04     40.000000
# 50%       29.000000   6.300000e+04   5.404900e+04     40.000000
# 75%       35.000000   1.250000e+05   9.500000e+04     44.000000
# max      279.000000  1.111111e+247   2.000000e+06    475.000000

# %%
df['ConvertedComp'].median()
# Out:
# 54049.0

# %%
schema_df
# Out:
#                                                                    QuestionText
# Column
# Respondent                    Randomized respondent ID number (not in order ...
# MainBranch                    Which of the following options best describes ...
# Hobbyist                                                Do you code as a hobby?
# Age                           What is your age (in years)? If you prefer not...
# Age1stCode                    At what age did you write your first line of c...
# CompFreq                       Is that compensation weekly, monthly, or yearly?
# CompTotal                     What is your current total compensation (salar...
# ConvertedComp                 Salary converted to annual USD salaries using ...
# Country                                                      Where do you live?
# CurrencyDesc                  Which currency do you use day-to-day? If your ...
# CurrencySymbol                Which currency do you use day-to-day? If your ...
# ...

# %%
df.median()
# Out:
# Age                 29.0
# CompTotal        63000.0
# ConvertedComp    54049.0
# WorkWeekHrs         40.0
# dtype: float64

# %%
df.mean()
# Out:
# Age               3.083411e+01
# CompTotal        3.190464e+242
# ConvertedComp     1.037561e+05
# WorkWeekHrs       4.078217e+01
# dtype: float64

# %%
df['ConvertedComp'].count()
# Out:
# 34756

# %%
df['Hobbyist']
# Out:
# Respondent
# 1        Yes
# 2         No
# 3        Yes
# 4        Yes
# 5        Yes
#         ...
# 64858    Yes
# 64867    Yes
# 64898    Yes
# 64925    Yes
# 65112    Yes
# Name: Hobbyist, Length: 64461, dtype: object

# %%
df['Hobbyist'].value_counts()
# Out:
# Yes    50388
# No     14028
# Name: Hobbyist, dtype: int64

# %%
df['ConvertedComp'].value_counts()
# Out:
# 120000.0     341
# 100000.0     306
# 150000.0     277
# 1000000.0    258
# 2000000.0    258
#             ...
# 230916.0       1
# 1135.0         1
# 348.0          1
# 132.0          1
# 44023.0        1
# Name: ConvertedComp, Length: 6958, dtype: int64

# %%
df['CurrencySymbol']
# Out:
# Respondent
# 1        EUR
# 2        GBP
# 3        NaN
# 4        ALL
# 5        NaN
#         ...
# 64858    NaN
# 64867    NaN
# 64898    NaN
# 64925    NaN
# 65112    NaN
# Name: CurrencySymbol, Length: 64461, dtype: object

# %%
schema_df.loc['CurrencySymbol']
# Out:
# QuestionText    Which currency do you use day-to-day? If your ...
# Name: CurrencySymbol, dtype: object

# %%
df['CurrencySymbol'].value_counts().head(10)
# Out:
# USD    11050
# EUR    10000
# INR     4930
# GBP     3127
# CAD     1570
# BRL     1308
# AUD      982
# PLN      937
# RUB      767
# SEK      666
# Name: CurrencySymbol, dtype: int64

# %%
# give result in percentage
df['CurrencySymbol'].value_counts(normalize = True).head(10)
# Out:
# USD    0.243007
# EUR    0.219916
# INR    0.108418
# GBP    0.068768
# CAD    0.034527
# BRL    0.028765
# AUD    0.021596
# PLN    0.020606
# RUB    0.016868
# SEK    0.014646
# Name: CurrencySymbol, dtype: float64

# %%
df['Country'].value_counts()
# Out:
# United States                         12469
# India                                  8403
# United Kingdom                         3896
# Germany                                3890
# Canada                                 2191
#                                       ...
# Chad                                      1
# Micronesia, Federated States of...        1
# Saint Lucia                               1
# Fiji                                      1
# Mali                                      1
# Name: Country, Length: 183, dtype: int64

# %%
country_grp = df.groupby(['Country'])

# %%
country_grp.get_group('India')
# Out:
#                                         MainBranch Hobbyist   Age Age1stCode  \
# Respondent
# 7                   I am a developer by profession      Yes   NaN         18
# 22                  I am a developer by profession      Yes   NaN         18
# 58                  I am a developer by profession      Yes   NaN         22
# 63          I am a student who is learning to code      Yes  21.0         17
# 149                 I am a developer by profession      Yes  36.0         31
# ...                                            ...      ...   ...        ...
# 54757                                          NaN      Yes   NaN         18
# 55407                                          NaN      Yes   NaN        NaN
# 62464                                          NaN      Yes   NaN        NaN
# 62954                                          NaN      Yes   NaN        NaN
# 64236                                          NaN      Yes   NaN        NaN
#
# ...

# %%
filt = df['Country'] == 'India'
df.loc[filt]['CurrencySymbol'].value_counts()
# Out:
# INR    4918
# USD     133
# AED      16
# AUD      11
# EUR       8
# AMD       7
# AFN       5
# DJF       2
# JPY       2
# ARS       2
# RON       2
# CAD       2
# ANG       2
# HKD       2
# AOA       2
# AWG       2
# RSD       1
# non       1
# TWD       1
# MKD       1
# RUB       1
# IDR       1
# BYN       1
# ETB       1
# YER       1
# BDT       1
# CDF       1
# GNF       1
# ZAR       1
# AZN       1
# NOK       1
# LKR       1
# UAH       1
# BMD       1
# MYR       1
# Name: CurrencySymbol, dtype: int64

# %%
country_grp['CurrencySymbol'].value_counts().head(50)
# Out:
# Country              CurrencySymbol
# Afghanistan          AFN                24
#                      AED                 3
#                      ALL                 2
#                      AUD                 2
#                      USD                 2
#                      ANG                 1
#                      RUB                 1
#                      THB                 1
# Albania              ALL                22
#                      EUR                 7
#                      AFN                 1
#                      AOA                 1
#                      BTN                 1
#                      USD                 1
# Algeria              DZD                25
#                      USD                 5
#                      EUR                 3
#                      ANG                 1
# Andorra              EUR                 3
#                      AED                 1
#                      ANG                 1
# ...

# %%
country_grp['CurrencySymbol'].value_counts().loc['India'].max()
# Out:
# 4918

# %%
country_grp['ConvertedComp'].median()
# Out:
# Country
# Afghanistan                             15163.5
# Albania                                 15900.0
# Algeria                                  9432.0
# Andorra                                 88640.0
# Angola                                   5292.0
#                                          ...
# Venezuela, Bolivarian Republic of...     3600.0
# Viet Nam                                10344.0
# Yemen                                   36000.0
# Zambia                                   5452.0
# Zimbabwe                                 7200.0
# Name: ConvertedComp, Length: 183, dtype: float64

# %%
country_grp['ConvertedComp'].median().loc['Germany']
# Out:
# 62697.0

# %%
country_grp['ConvertedComp'].agg(['median', 'mean']).loc['Canada']
# Out:
# median     68068.000000
# mean      115101.775465
# Name: Canada, dtype: float64

# %%
filt = df['Country'] == 'India'
df.loc[filt]['LanguageWorkedWith'].str.contains('Python').sum()
# Out:
# 2670

# %%
country_grp.sum()
# Out:
#                                          Age     CompTotal  ConvertedComp  \
# Country
# Afghanistan                            518.0  1.427182e+10      3558963.0
# Albania                                803.0  2.247393e+06       512220.0
# Algeria                               1429.0  1.158900e+06       165805.0
# Andorra                                117.0  1.640000e+05       177280.0
# Angola                                 120.0  2.374040e+05        10584.0
# ...                                      ...           ...            ...
# Venezuela, Bolivarian Republic of...  1624.0  7.032049e+07       226102.0
# Viet Nam                              4234.0  4.958551e+16      2947631.0
# Yemen                                   62.0  3.000000e+03        36000.0
# Zambia                                 282.0  1.120000e+05        87532.0
# Zimbabwe                               486.0  5.211000e+04       289720.0
#
#                                       WorkWeekHrs
# Country
# ...

# %%
country_grp.count()
# Out:
#                                       MainBranch  Hobbyist  Age  Age1stCode  \
# Country
# Afghanistan                                   80        84   22          52
# Albania                                       53        54   30          45
# Algeria                                       90        94   51          75
# Andorra                                       13        13    3           7
# Angola                                         9         9    3           4
# ...                                          ...       ...  ...         ...
# Venezuela, Bolivarian Republic of...          70        70   56          63
# Viet Nam                                     362       364  165         273
# Yemen                                          7         7    2           5
# Zambia                                        20        21   10          17
# Zimbabwe                                      31        31   19          25
#
# ...

# %%
country_grp['LanguageWorkedWith'].apply(lambda x: x.str.contains('Python').sum()).loc['India']
# Out:
# 2670

# %%
country_respondents = df['Country'].value_counts()
country_respondents
# Out:
# United States                         12469
# India                                  8403
# United Kingdom                         3896
# Germany                                3890
# Canada                                 2191
#                                       ...
# Chad                                      1
# Micronesia, Federated States of...        1
# Saint Lucia                               1
# Fiji                                      1
# Mali                                      1
# Name: Country, Length: 183, dtype: int64

# %%
country_uses_python = country_grp['LanguageWorkedWith'].apply(lambda x: x.str.contains('Python').sum())
country_uses_python
# Out:
# Country
# Afghanistan                              11
# Albania                                  13
# Algeria                                  40
# Andorra                                   3
# Angola                                    1
#                                        ...
# Venezuela, Bolivarian Republic of...     29
# Viet Nam                                102
# Yemen                                     1
# Zambia                                    4
# Zimbabwe                                 13
# Name: LanguageWorkedWith, Length: 183, dtype: int64

# %%
python_df = pd.concat([country_respondents, country_uses_python], axis='columns', sort=False)
python_df
# Out:
#                                     Country  LanguageWorkedWith
# United States                         12469                5964
# India                                  8403                2670
# United Kingdom                         3896                1621
# Germany                                3890                1712
# Canada                                 2191                1011
# ...                                     ...                 ...
# Chad                                      1                   0
# Micronesia, Federated States of...        1                   1
# Saint Lucia                               1                   1
# Fiji                                      1                   0
# Mali                                      1                   0
#
# [183 rows x 2 columns]

# %%
python_df.rename(columns={'Country': 'NumRespondents', 'LanguageWorkedWith': 'NumKnowsPython'}, inplace=True)

# %%
python_df
# Out:
#                                     NumRespondents  NumKnowsPython
# United States                                12469            5964
# India                                         8403            2670
# United Kingdom                                3896            1621
# Germany                                       3890            1712
# Canada                                        2191            1011
# ...                                            ...             ...
# Chad                                             1               0
# Micronesia, Federated States of...               1               1
# Saint Lucia                                      1               1
# Fiji                                             1               0
# Mali                                             1               0
#
# [183 rows x 2 columns]

# %%
python_df['PctKnowsPython'] = (python_df['NumKnowsPython']/python_df['NumRespondents']) * 100
python_df
# Out:
#                                     NumRespondents  NumKnowsPython  \
# United States                                12469            5964
# India                                         8403            2670
# United Kingdom                                3896            1621
# Germany                                       3890            1712
# Canada                                        2191            1011
# ...                                            ...             ...
# Chad                                             1               0
# Micronesia, Federated States of...               1               1
# Saint Lucia                                      1               1
# Fiji                                             1               0
# Mali                                             1               0
#
#                                     PctKnowsPython
# United States                            47.830620
# India                                    31.774366
# ...

# %%
python_df.sort_values(by='PctKnowsPython', ascending=False, inplace=True)

# %%
python_df.head(50)
# Out:
#                                       NumRespondents  NumKnowsPython  \
# Gabon                                              1               1
# Saint Lucia                                        1               1
# Micronesia, Federated States of...                 1               1
# Montenegro                                        13               9
# Brunei Darussalam                                  3               2
# Guyana                                             5               3
# Swaziland                                          7               4
# Iceland                                           53              28
# Finland                                          349             183
# Uganda                                            81              42
# Mauritania                                         4               2
# Solomon Islands                                    2               1
# Burkina Faso                                       6               3
# ...

# %%
python_df.loc['India']
# Out:
# NumRespondents    8403.000000
# NumKnowsPython    2670.000000
# PctKnowsPython      31.774366
# Name: India, dtype: float64

# %%
filt = df['Country'] == 'India'
df.loc[filt]['CurrencySymbol'].value_counts(ascending = True).index[0]
# Out:
# 'non'
