# %% [markdown]
# Hypothesis testing, statistical significance, and using scipy to run student's t-tests.
#
#
# The p value reports the probability we can get the observed data under the null hypothesis, so with a larger p value (by larger we mean it is closer to 1, instead of saying that it is more extreme), we have less evidence to reject the null hypothesis.
#
# It is important to understand the definition of significance here: significance means the evidence we observed from the data against the null hypothesis, the p value is a measure of the significance.
#
# With a larger alpha, we reject the null hypothesis less carefully.

# %%
# We use statistics in a lot of different ways in data science, and on this lecture, I want to refresh your
# knowledge of hypothesis testing, which is a core data analysis activity behind experimentation. The goal of
# hypothesis testing is to determine if, for instance, the two different conditions we have in an experiment 
# have resulted in different impacts

# Let's import our usual numpy and pandas libraries
import numpy as np
import pandas as pd

# Now let's bring in some new libraries from scipy
from scipy import stats

# %%
# Now, scipy is an interesting collection of libraries for data science and you'll use most or perpahs all of
# these libraries. It includes numpy and pandas, but also plotting libraries such as matplotlib, and a
# number of scientific library functions as well

# %%
# When we do hypothesis testing, we actually have two statements of interest: the first is our actual
# explanation, which we call the alternative hypothesis, and the second is that the explanation we have is not
# sufficient, and we call this the null hypothesis. Our actual testing method is to determine whether the null
# hypothesis is true or not. If we find that there is a difference between groups, then we can reject the null
# hypothesis and we accept our alternative.

# Let's see an example of this; we're going to use some grade data
df=pd.read_csv ('grades.csv')
df.head()
# Out:
#                              student_id  assignment1_grade  \
# 0  B73F2C11-70F0-E37D-8B10-1D20AFED50B1          92.733946
# 1  98A0FAE0-A19A-13D2-4BB5-CFBFD94031D1          86.790821
# 2  D0F62040-CEB0-904C-F563-2F8620916C4E          85.512541
# 3  FFDF2B2C-F514-EF7F-6538-A6A53518E9DC          86.030665
# 4  5ECBEEB6-F1CE-80AE-3164-E45E99473FB4          64.813800
#
#           assignment1_submission  assignment2_grade  \
# 0  2015-11-02 06:55:34.282000000          83.030552
# 1  2015-11-29 14:57:44.429000000          86.290821
# 2  2016-01-09 05:36:02.389000000          85.512541
# 3  2016-04-30 06:50:39.801000000          68.824532
# 4  2015-12-13 17:06:10.750000000          51.491040
#
#           assignment2_submission  assignment3_grade  \
# 0  2015-11-09 02:22:58.938000000          67.164441
# 1  2015-12-06 17:41:18.449000000          69.772657
# 2  2016-01-09 06:39:44.416000000          68.410033
# 3  2016-04-30 17:20:38.727000000          61.942079
# 4  2015-12-14 12:25:12.056000000          41.932832
#
#           assignment3_submission  assignment4_grade  \
# 0  2015-11-12 08:58:33.998000000          53.011553
# 1  2015-12-10 08:54:55.904000000          55.098125
# 2  2016-01-15 20:22:45.882000000          54.728026
# 3  2016-05-12 07:47:16.326000000          49.553663
# 4  2015-12-29 14:25:22.594000000          36.929549
#
#           assignment4_submission  assignment5_grade  \
# 0  2015-11-16 01:21:24.663000000          47.710398
# 1  2015-12-13 17:32:30.941000000          49.588313
# 2  2016-01-11 12:41:50.749000000          49.255224
# 3  2016-05-07 16:09:20.485000000          49.553663
# 4  2015-12-28 01:29:55.901000000          33.236594
#
#           assignment5_submission  assignment6_grade  \
# 0  2015-11-20 13:24:59.692000000          38.168318
# 1  2015-12-19 23:26:39.285000000          44.629482
# 2  2016-01-11 17:31:12.489000000          44.329701
# 3  2016-05-24 12:51:18.016000000          44.598297
# 4  2015-12-29 14:46:06.628000000          33.236594
#
#           assignment6_submission
# 0  2015-11-22 18:31:15.934000000
# 1  2015-12-21 17:07:24.275000000
# 2  2016-01-17 16:24:42.765000000
# 3  2016-05-26 08:09:12.058000000
# 4  2016-01-05 01:06:59.546000000

# %%
# If we take a look at the data frame inside, we see we have six different assignments. Lets look at some
# summary statistics for this DataFrame
print("There are {} rows and {} columns".format(df.shape[0], df.shape[1]))
# Out:
# There are 2315 rows and 13 columns

# %%
# Let's say those who finish
# the first assignment by the end of December 2015, we'll call them early finishers, and those who finish it 
# sometime after that, we'll call them late finishers.

early_finishers=df[pd.to_datetime(df['assignment1_submission']) < '2016']
early_finishers.head()
# Out:
#                              student_id  assignment1_grade  \
# 0  B73F2C11-70F0-E37D-8B10-1D20AFED50B1          92.733946
# 1  98A0FAE0-A19A-13D2-4BB5-CFBFD94031D1          86.790821
# 4  5ECBEEB6-F1CE-80AE-3164-E45E99473FB4          64.813800
# 5  D09000A0-827B-C0FF-3433-BF8FF286E15B          71.647278
# 8  C9D51293-BD58-F113-4167-A7C0BAFCB6E5          66.595568
#
#           assignment1_submission  assignment2_grade  \
# 0  2015-11-02 06:55:34.282000000          83.030552
# 1  2015-11-29 14:57:44.429000000          86.290821
# 4  2015-12-13 17:06:10.750000000          51.491040
# 5  2015-12-28 04:35:32.836000000          64.052550
# 8  2015-12-25 02:29:28.415000000          52.916454
#
#           assignment2_submission  assignment3_grade  \
# 0  2015-11-09 02:22:58.938000000          67.164441
# 1  2015-12-06 17:41:18.449000000          69.772657
# 4  2015-12-14 12:25:12.056000000          41.932832
# 5  2016-01-03 21:05:38.392000000          64.752550
# 8  2015-12-31 01:42:30.046000000          48.344809
#
#           assignment3_submission  assignment4_grade  \
# 0  2015-11-12 08:58:33.998000000          53.011553
# 1  2015-12-10 08:54:55.904000000          55.098125
# 4  2015-12-29 14:25:22.594000000          36.929549
# 5  2016-01-07 08:55:43.692000000          57.467295
# 8  2016-01-05 23:34:02.180000000          47.444809
#
#           assignment4_submission  assignment5_grade  \
# 0  2015-11-16 01:21:24.663000000          47.710398
# 1  2015-12-13 17:32:30.941000000          49.588313
# 4  2015-12-28 01:29:55.901000000          33.236594
# 5  2016-01-11 00:45:28.706000000          57.467295
# 8  2016-01-02 07:48:42.517000000          37.955847
#
#           assignment5_submission  assignment6_grade  \
# 0  2015-11-20 13:24:59.692000000          38.168318
# 1  2015-12-19 23:26:39.285000000          44.629482
# 4  2015-12-29 14:46:06.628000000          33.236594
# 5  2016-01-11 00:54:13.579000000          57.467295
# 8  2016-01-03 21:27:04.266000000          37.955847
#
#           assignment6_submission
# 0  2015-11-22 18:31:15.934000000
# 1  2015-12-21 17:07:24.275000000
# 4  2016-01-05 01:06:59.546000000
# 5  2016-01-20 19:54:46.166000000
# 8  2016-01-19 15:24:31.060000000

# %%
late_finishers = df[~df.index.isin(early_finishers.index)]
late_finishers.head()
# Out:
#                              student_id  assignment1_grade  \
# 2  D0F62040-CEB0-904C-F563-2F8620916C4E          85.512541
# 3  FFDF2B2C-F514-EF7F-6538-A6A53518E9DC          86.030665
# 6  3217BE3F-E4B0-C3B6-9F64-462456819CE4          87.498744
# 7  F1CB5AA1-B3DE-5460-FAFF-BE951FD38B5F          80.576090
# 9  E2C617C2-4654-622C-AB50-1550C4BE42A0          59.270882
#
#           assignment1_submission  assignment2_grade  \
# 2  2016-01-09 05:36:02.389000000          85.512541
# 3  2016-04-30 06:50:39.801000000          68.824532
# 6  2016-03-05 11:05:25.408000000          69.998995
# 7  2016-01-24 18:24:25.619000000          72.518481
# 9  2016-03-06 12:06:26.185000000          59.270882
#
#           assignment2_submission  assignment3_grade  \
# 2  2016-01-09 06:39:44.416000000          68.410033
# 3  2016-04-30 17:20:38.727000000          61.942079
# 6  2016-03-09 07:29:52.405000000          55.999196
# 7  2016-01-27 13:37:12.943000000          65.266633
# 9  2016-03-13 02:07:25.289000000          53.343794
#
#           assignment3_submission  assignment4_grade  \
# 2  2016-01-15 20:22:45.882000000          54.728026
# 3  2016-05-12 07:47:16.326000000          49.553663
# 6  2016-03-16 22:31:24.316000000          50.399276
# 7  2016-01-30 14:34:36.581000000          65.266633
# 9  2016-03-17 07:30:09.241000000          53.343794
#
#           assignment4_submission  assignment5_grade  \
# 2  2016-01-11 12:41:50.749000000          49.255224
# 3  2016-05-07 16:09:20.485000000          49.553663
# 6  2016-03-18 07:19:26.032000000          45.359349
# 7  2016-02-03 22:08:49.002000000          65.266633
# 9  2016-03-20 21:45:56.229000000          42.675035
#
#           assignment5_submission  assignment6_grade  \
# 2  2016-01-11 17:31:12.489000000          44.329701
# 3  2016-05-24 12:51:18.016000000          44.598297
# 6  2016-03-19 10:35:41.869000000          45.359349
# 7  2016-02-16 14:22:23.664000000          65.266633
# 9  2016-03-27 15:55:04.414000000          38.407532
#
#           assignment6_submission
# 2  2016-01-17 16:24:42.765000000
# 3  2016-05-26 08:09:12.058000000
# 6  2016-03-23 14:02:00.987000000
# 7  2016-02-18 08:35:04.796000000
# 9  2016-03-30 20:33:13.554000000

# %%
# There are lots of other ways to do this. For instance, you could just copy and paste the first projection
# and change the sign from less than to greater than or equal to. This is ok, but if you decide you want to
# change the date down the road you have to remember to change it in two places. You could also do a join of
# the dataframe df with early_finishers - if you do a left join you only keep the items in the left dataframe,
# so this would have been a good answer. You also could have written a function that determines if someone is
# early or late, and then called .apply() on the dataframe and added a new column to the dataframe. This is a
# pretty reasonable answer as well.

# %%
# As you've seen, the pandas data frame object has a variety of statistical functions associated with it. If
# we call the mean function directly on the data frame, we see that each of the means for the assignments are
# calculated. Let's compare the means for our two populations

print(early_finishers['assignment1_grade'].mean())
print(late_finishers['assignment1_grade'].mean())
# Out:
# 74.94728457024304
# 74.0450648477065

# %%
# Ok, these look pretty similar. But, are they the same? What do we mean by similar? This is where the
# students' t-test comes in. It allows us to form the alternative hypothesis ("These are different") as well
# as the null hypothesis ("These are the same") and then test that null hypothesis.

# When doing hypothesis testing, we have to choose a significance level as a threshold for how much of a
# chance we're willing to accept. This significance level is typically called alpha. #For this example, let's
# use a threshold of 0.05 for our alpha or 5%. Now this is a commonly used number but it's really quite
# arbitrary.

# The SciPy library contains a number of different statistical tests and forms a basis for hypothesis testing
# in Python and we're going to use the ttest_ind() function which does an independent t-test (meaning the
# populations are not related to one another). The result of ttest_index() are the t-statistic and a p-value.
# It's this latter value, the probability, which is most important to us, as it indicates the chance (between
# 0 and 1) of our null hypothesis being True.

# Let's bring in our ttest_ind function
from scipy.stats import ttest_ind

# Let's run this function with our two populations, looking at the assignment 1 grades
ttest_ind(early_finishers['assignment1_grade'], late_finishers['assignment1_grade'])
# Out:
# Ttest_indResult(statistic=1.3223540853721596, pvalue=0.18618101101713855)

# %%
# So here we see that the probability is 0.18, and this is above our alpha value of 0.05. This means that we
# cannot reject the null hypothesis. The null hypothesis was that the two populations are the same, and we
# don't have enough certainty in our evidence (because it is greater than alpha) to come to a conclusion to
# the contrary. This doesn't mean that we have proven the populations are the same.

# %%
# Why don't we check the other assignment grades?
print(ttest_ind(early_finishers['assignment2_grade'], late_finishers['assignment2_grade']))
print(ttest_ind(early_finishers['assignment3_grade'], late_finishers['assignment3_grade']))
print(ttest_ind(early_finishers['assignment4_grade'], late_finishers['assignment4_grade']))
print(ttest_ind(early_finishers['assignment5_grade'], late_finishers['assignment5_grade']))
print(ttest_ind(early_finishers['assignment6_grade'], late_finishers['assignment6_grade']))
# Out:
# Ttest_indResult(statistic=1.2514717608216366, pvalue=0.2108889627004424)
# Ttest_indResult(statistic=1.6133726558705392, pvalue=0.10679998102227865)
# Ttest_indResult(statistic=0.049671157386456125, pvalue=0.960388729789337)
# Ttest_indResult(statistic=-0.05279315545404755, pvalue=0.9579012739746492)
# Ttest_indResult(statistic=-0.11609743352612056, pvalue=0.9075854011989656)

# %%
# Ok, so it looks like in this data we do not have enough evidence to suggest the populations differ with
# respect to grade. Let's take a look at those p-values for a moment though, because they are saying things
# that can inform experimental design down the road. For instance, one of the assignments, assignment 3, has a
# p-value around 0.1. This means that if we accepted a level of chance similarity of 11% this would have been
# considered statistically significant. As a research, this would suggest to me that there is something here
# worth considering following up on. For instance, if we had a small number of participants (we don't) or if
# there was something unique about this assignment as it relates to our experiment (whatever it was) then
# there may be followup experiments we could run.

# %%
# P-values have come under fire recently for being insuficient for telling us enough about the interactions
# which are happening, and two other techniques, confidence intervalues and bayesian analyses, are being used
# more regularly. One issue with p-values is that as you run more tests you are likely to get a value which
# is statistically significant just by chance.

# Lets see a simulation of this. First, lets create a data frame of 100 columns, each with 100 numbers
df1=pd.DataFrame([np.random.random(100) for x in range(100)])
df1.head()
# Out:
#          0         1         2         3         4         5         6   \
# 0  0.886102  0.362093  0.479059  0.940635  0.210547  0.179908  0.901649
# 1  0.296046  0.541260  0.125377  0.005320  0.647162  0.882954  0.422721
# 2  0.449521  0.058778  0.306872  0.529777  0.221074  0.470987  0.287070
# 3  0.811282  0.219129  0.161460  0.150053  0.866334  0.722655  0.613388
# 4  0.819763  0.848980  0.348136  0.052736  0.505569  0.805923  0.580292
#
#          7         8         9   ...        90        91        92        93  \
# 0  0.391393  0.054710  0.529413  ...  0.962390  0.366814  0.123570  0.878595
# 1  0.031139  0.497524  0.837230  ...  0.969787  0.401516  0.572593  0.553317
# 2  0.621011  0.143552  0.447063  ...  0.611599  0.515861  0.910305  0.768957
# 3  0.506698  0.941609  0.159680  ...  0.181031  0.499212  0.300363  0.657941
# 4  0.656215  0.877606  0.359137  ...  0.333959  0.246548  0.125644  0.167351
#
#          94        95        96        97        98        99
# 0  0.538857  0.997948  0.379754  0.492626  0.661179  0.988150
# 1  0.664461  0.132028  0.126431  0.652837  0.368909  0.083342
# 2  0.188900  0.560635  0.856257  0.309593  0.098416  0.948193
# 3  0.988986  0.742941  0.140099  0.837486  0.803081  0.268244
# 4  0.473363  0.387183  0.959249  0.866150  0.354524  0.612643
#
# [5 rows x 100 columns]

# %%
# Ok, let's create a second dataframe
df2=pd.DataFrame([np.random.random(100) for x in range(100)])
df2.head()
# Out:
#          0         1         2         3         4         5         6   \
# 0  0.837384  0.323537  0.857199  0.790012  0.641488  0.921429  0.679240
# 1  0.735160  0.319782  0.037215  0.585904  0.563671  0.016289  0.974216
# 2  0.608119  0.803307  0.793172  0.874359  0.864389  0.245268  0.762930
# 3  0.125161  0.284438  0.818882  0.248442  0.082559  0.536540  0.186144
# 4  0.339868  0.592882  0.509821  0.919990  0.006201  0.326774  0.391089
#
#          7         8         9   ...        90        91        92        93  \
# 0  0.501566  0.554297  0.994964  ...  0.173980  0.417306  0.641424  0.346379
# 1  0.962140  0.142054  0.265023  ...  0.117635  0.955922  0.243527  0.003411
# 2  0.083970  0.169901  0.452705  ...  0.208563  0.535745  0.576283  0.408128
# 3  0.769147  0.546820  0.233542  ...  0.012394  0.275979  0.929708  0.828584
# 4  0.727808  0.674484  0.176788  ...  0.766430  0.814915  0.745560  0.062772
#
#          94        95        96        97        98        99
# 0  0.361851  0.847608  0.543060  0.862635  0.691943  0.990015
# 1  0.250216  0.869522  0.798401  0.951959  0.639151  0.248177
# 2  0.200136  0.324051  0.017323  0.188107  0.046505  0.995143
# 3  0.772705  0.219257  0.254424  0.467398  0.764421  0.378443
# 4  0.052498  0.635666  0.506039  0.380163  0.802974  0.443217
#
# [5 rows x 100 columns]

# %%
# Are these two DataFrames the same? Maybe a better question is, for a given row inside of df1, is it the same
# as the row inside df2?

# Let's take a look. Let's say our critical value is 0.1, or and alpha of 10%. And we're going to compare each
# column in df1 to the same numbered column in df2. And we'll report when the p-value isn't less than 10%,
# which means that we have sufficient evidence to say that the columns are different.

# Let's write this in a function called test_columns
def test_columns(alpha=0.1):
    # I want to keep track of how many differ
    num_diff=0
    # And now we can just iterate over the columns
    for col in df1.columns:
        # we can run out ttest_ind between the two dataframes
        teststat,pval=ttest_ind(df1[col],df2[col])
        # and we check the pvalue versus the alpha
        if pval<=alpha:
            # And now we'll just print out if they are different and increment the num_diff
            print("Col {} is statistically significantly different at alpha={}, pval={}".format(col,alpha,pval))
            num_diff=num_diff+1
    # and let's print out some summary stats
    print("Total number different was {}, which is {}%".format(num_diff,float(num_diff)/len(df1.columns)*100))

# And now lets actually run this
test_columns()
# Out:
# Col 10 is statistically significantly different at alpha=0.1, pval=0.0451385939152149
# Col 14 is statistically significantly different at alpha=0.1, pval=0.04546295444779714
# Col 15 is statistically significantly different at alpha=0.1, pval=0.0972080308585791
# Col 17 is statistically significantly different at alpha=0.1, pval=0.06898401852697736
# Col 26 is statistically significantly different at alpha=0.1, pval=0.08379757343781415
# Col 40 is statistically significantly different at alpha=0.1, pval=0.0915958201247319
# Col 49 is statistically significantly different at alpha=0.1, pval=0.023193054458420768
# Col 62 is statistically significantly different at alpha=0.1, pval=0.08369381094111066
# Col 65 is statistically significantly different at alpha=0.1, pval=0.027102801313879453
# Col 85 is statistically significantly different at alpha=0.1, pval=0.04971641446659637
# Col 88 is statistically significantly different at alpha=0.1, pval=0.07894178739233697
# Col 92 is statistically significantly different at alpha=0.1, pval=0.09162400825387565
# Total number different was 12, which is 12.0%

# %%
# Interesting, so we see that there are a bunch of columns that are different! In fact, that number looks a
# lot like the alpha value we chose. So what's going on - shouldn't all of the columns be the same? Remember
# that all the ttest does is check if two sets are similar given some level of confidence, in our case, 10%.
# The more random comparisons you do, the more will just happen to be the same by chance. In this example, we
# checked 100 columns, so we would expect there to be roughly 10 of them if our alpha was 0.1.

# We can test some other alpha values as well
test_columns(0.05)
# Out:
# Col 10 is statistically significantly different at alpha=0.05, pval=0.0451385939152149
# Col 14 is statistically significantly different at alpha=0.05, pval=0.04546295444779714
# Col 49 is statistically significantly different at alpha=0.05, pval=0.023193054458420768
# Col 65 is statistically significantly different at alpha=0.05, pval=0.027102801313879453
# Col 85 is statistically significantly different at alpha=0.05, pval=0.04971641446659637
# Total number different was 5, which is 5.0%

# %%
# So, keep this in mind when you are doing statistical tests like the t-test which has a p-value. Understand
# that this p-value isn't magic, that it's a threshold for you when reporting results and trying to answer
# your hypothesis. What's a reasonable threshold? Depends on your question, and you need to engage domain
# experts to better understand what they would consider significant.

# Just for fun, lets recreate that second dataframe using a non-normal distribution, I'll arbitrarily chose
# chi squared
df2=pd.DataFrame([np.random.chisquare(df=1,size=100) for x in range(100)])
test_columns()
# Out:
# Col 0 is statistically significantly different at alpha=0.1, pval=1.5047551071733795e-05
# Col 1 is statistically significantly different at alpha=0.1, pval=3.5481906740613023e-06
# Col 2 is statistically significantly different at alpha=0.1, pval=2.1710419844352725e-05
# Col 3 is statistically significantly different at alpha=0.1, pval=0.0038417133386242407
# Col 4 is statistically significantly different at alpha=0.1, pval=0.004984185338464335
# Col 5 is statistically significantly different at alpha=0.1, pval=0.00151694966970864
# Col 6 is statistically significantly different at alpha=0.1, pval=0.03132961355443301
# Col 7 is statistically significantly different at alpha=0.1, pval=0.014838804279128192
# Col 8 is statistically significantly different at alpha=0.1, pval=0.04898722873340633
# Col 9 is statistically significantly different at alpha=0.1, pval=0.00015173667832656863
# Col 10 is statistically significantly different at alpha=0.1, pval=0.0003241394509004822
# Col 11 is statistically significantly different at alpha=0.1, pval=0.0002923861331030805
# Col 12 is statistically significantly different at alpha=0.1, pval=2.2360665519646065e-05
# Col 13 is statistically significantly different at alpha=0.1, pval=0.012433699126134755
# Col 14 is statistically significantly different at alpha=0.1, pval=0.0013895793001818806
# Col 15 is statistically significantly different at alpha=0.1, pval=0.0047212379865610695
# Col 16 is statistically significantly different at alpha=0.1, pval=9.525050953133917e-05
# Col 17 is statistically significantly different at alpha=0.1, pval=0.006409954753479564
# Col 18 is statistically significantly different at alpha=0.1, pval=1.5327711751502016e-05
# Col 19 is statistically significantly different at alpha=0.1, pval=0.0013020357296402358
# Col 20 is statistically significantly different at alpha=0.1, pval=0.007251504923472659
# Col 21 is statistically significantly different at alpha=0.1, pval=0.000124006547143316
# Col 22 is statistically significantly different at alpha=0.1, pval=0.0012515220193433498
# Col 23 is statistically significantly different at alpha=0.1, pval=7.887126810221285e-05
# Col 24 is statistically significantly different at alpha=0.1, pval=5.877422759915763e-06
# Col 25 is statistically significantly different at alpha=0.1, pval=0.005668945471166827
# Col 26 is statistically significantly different at alpha=0.1, pval=0.00230444613063522
# Col 27 is statistically significantly different at alpha=0.1, pval=7.014020498125461e-06
# Col 28 is statistically significantly different at alpha=0.1, pval=0.0010082871437580446
# Col 29 is statistically significantly different at alpha=0.1, pval=1.2118841700151305e-05
# Col 30 is statistically significantly different at alpha=0.1, pval=0.00038841043191353527
# Col 31 is statistically significantly different at alpha=0.1, pval=7.936658476945e-05
# Col 32 is statistically significantly different at alpha=0.1, pval=9.967070527562848e-06
# Col 33 is statistically significantly different at alpha=0.1, pval=0.0008445633894969398
# Col 34 is statistically significantly different at alpha=0.1, pval=0.0003650651985617964
# Col 35 is statistically significantly different at alpha=0.1, pval=0.001360343018634725
# Col 36 is statistically significantly different at alpha=0.1, pval=3.5404691452559886e-06
# Col 37 is statistically significantly different at alpha=0.1, pval=1.9775767673822066e-05
# Col 38 is statistically significantly different at alpha=0.1, pval=0.003283206929826666
# Col 39 is statistically significantly different at alpha=0.1, pval=2.4557570985029822e-05
# Col 40 is statistically significantly different at alpha=0.1, pval=0.002310201033742808
# Col 41 is statistically significantly different at alpha=0.1, pval=0.0009929479773480951
# Col 42 is statistically significantly different at alpha=0.1, pval=0.00032614575708488005
# Col 43 is statistically significantly different at alpha=0.1, pval=2.554593366903352e-07
# Col 44 is statistically significantly different at alpha=0.1, pval=0.00019731117106989264
# Col 45 is statistically significantly different at alpha=0.1, pval=0.0006613476025098958
# Col 46 is statistically significantly different at alpha=0.1, pval=0.002049348738184061
# Col 47 is statistically significantly different at alpha=0.1, pval=0.0007158963561416233
# Col 48 is statistically significantly different at alpha=0.1, pval=0.0028445943347814007
# Col 49 is statistically significantly different at alpha=0.1, pval=5.167408675173708e-06
# Col 50 is statistically significantly different at alpha=0.1, pval=5.081803534951523e-05
# Col 51 is statistically significantly different at alpha=0.1, pval=0.0010423618496814913
# Col 52 is statistically significantly different at alpha=0.1, pval=0.0004088122828778128
# Col 53 is statistically significantly different at alpha=0.1, pval=5.529788839261411e-05
# Col 54 is statistically significantly different at alpha=0.1, pval=0.0004920674201452943
# Col 55 is statistically significantly different at alpha=0.1, pval=5.952330011814615e-06
# Col 56 is statistically significantly different at alpha=0.1, pval=0.0014062479472525874
# Col 57 is statistically significantly different at alpha=0.1, pval=0.0002448496434460078
# Col 58 is statistically significantly different at alpha=0.1, pval=0.0011631033216664916
# Col 59 is statistically significantly different at alpha=0.1, pval=0.0009914675692630273
# Col 60 is statistically significantly different at alpha=0.1, pval=0.005645641034992296
# Col 61 is statistically significantly different at alpha=0.1, pval=0.0004149529513729479
# Col 62 is statistically significantly different at alpha=0.1, pval=1.9753844611644544e-06
# Col 63 is statistically significantly different at alpha=0.1, pval=6.32562709259255e-05
# Col 64 is statistically significantly different at alpha=0.1, pval=0.0003601013186789849
# Col 65 is statistically significantly different at alpha=0.1, pval=0.00021533808077880986
# Col 66 is statistically significantly different at alpha=0.1, pval=8.371600658780217e-05
# Col 67 is statistically significantly different at alpha=0.1, pval=0.0019982836804901634
# Col 68 is statistically significantly different at alpha=0.1, pval=0.0004563100755726326
# Col 69 is statistically significantly different at alpha=0.1, pval=0.0011033042370310116
# Col 70 is statistically significantly different at alpha=0.1, pval=0.0002717454552993364
# Col 71 is statistically significantly different at alpha=0.1, pval=0.0008651713846147067
# Col 72 is statistically significantly different at alpha=0.1, pval=0.004137084629599699
# Col 73 is statistically significantly different at alpha=0.1, pval=0.0024192175915238867
# Col 74 is statistically significantly different at alpha=0.1, pval=0.03073950525372762
# Col 75 is statistically significantly different at alpha=0.1, pval=3.56509944303671e-05
# Col 76 is statistically significantly different at alpha=0.1, pval=2.770731926058579e-05
# Col 77 is statistically significantly different at alpha=0.1, pval=0.0027607601239611223
# Col 78 is statistically significantly different at alpha=0.1, pval=3.6892120223945625e-05
# Col 79 is statistically significantly different at alpha=0.1, pval=0.0025122827411949247
# Col 80 is statistically significantly different at alpha=0.1, pval=2.1737817442509687e-05
# Col 81 is statistically significantly different at alpha=0.1, pval=0.006029470447353826
# Col 82 is statistically significantly different at alpha=0.1, pval=0.003926907867513509
# Col 83 is statistically significantly different at alpha=0.1, pval=0.0028509917869449833
# Col 84 is statistically significantly different at alpha=0.1, pval=3.761053766525791e-05
# Col 85 is statistically significantly different at alpha=0.1, pval=0.0012824112130217832
# Col 86 is statistically significantly different at alpha=0.1, pval=0.046356655725508684
# Col 87 is statistically significantly different at alpha=0.1, pval=4.335895093455337e-05
# Col 88 is statistically significantly different at alpha=0.1, pval=0.0008038809831407167
# Col 89 is statistically significantly different at alpha=0.1, pval=0.004762205419497041
# Col 90 is statistically significantly different at alpha=0.1, pval=0.0019031900315062925
# Col 91 is statistically significantly different at alpha=0.1, pval=4.840969737973646e-05
# Col 92 is statistically significantly different at alpha=0.1, pval=4.5483794498209425e-06
# Col 93 is statistically significantly different at alpha=0.1, pval=0.00011886017007753716
# Col 94 is statistically significantly different at alpha=0.1, pval=8.37541172873573e-05
# Col 95 is statistically significantly different at alpha=0.1, pval=0.0036697593346824635
# Col 96 is statistically significantly different at alpha=0.1, pval=5.7405106918668665e-06
# Col 97 is statistically significantly different at alpha=0.1, pval=0.0004138203931756569
# Col 98 is statistically significantly different at alpha=0.1, pval=0.07028720633979124
# Col 99 is statistically significantly different at alpha=0.1, pval=0.0009457902854752362
# Total number different was 100, which is 100.0%

# %%
# Now we see that all or most columns test to be statistically significant at the 10% level.

# %% [markdown]
# There's much more to learn about hypothesis testing, for instance, there are different tests used, depending on the shape of your data and different ways to report results instead of just p-values such as confidence intervals or bayesian analyses. But this should give you a basic idea of where to start when comparing two populations for differences, which is a common task for data scientists.
